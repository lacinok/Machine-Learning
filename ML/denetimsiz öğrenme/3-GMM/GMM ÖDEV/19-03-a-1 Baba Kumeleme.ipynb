# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn import cluster, preprocessing, pipeline

# %%
baba = plt.imread("orhan_baba.jpg")

# %%
plt.imshow(baba);

# %% [markdown]
# # 1. 8-renkli baba

# %% [markdown]
# Orhan babanin yukaridaki resmini yalnizca 8 renk kullanarak yeniden olusturmak istiyoruz.
#
# Bu sirada K-Means'den faydalanmak icin asagidaki adimlari izleyecegiz:
# - Orhan babayi tekrar sekillendirip (m, 3) bir matris haline getirmek (3 renkle temsil edilen her bir pikseli alt alta koymus olduk - RGB)
# - Duz babayi K-Means algoritmasi ile 8 kumeye ayiriyoruz.
# - Her pikseli, kendisine en yakin kume merkezi ile degistiriyoruz.
# - Duzledigimiz pikselleri eski sekline topluyoruz.
# - Gerekli son dokunuslari yapip gorselimizi sergiliyoruz.

# %% [markdown]
# Adimlari dogru bir sekilde uygularsak asagidaki sekle benzer bir sekil elde edecegiz.

# %% [markdown]
# ![baba 8 renk](baba_8_renk.jpg)

# %% [markdown]
# Gerekli islemleri asagida yapiniz.

# %% [markdown]
# # 2. Farkliliklar

# %% [markdown]
# Islemleri dogru yapmaniza ragmen farkli bir sonuc almis olabilirsiniz. Bunun sebebi ne(ler) olabilir? Aciklayiniz.

# %% [markdown]
# # 3. Ideal renk sayisi

# %% [markdown]
# Babayi temsil etmek icin ideal oldugunu dusundugunuz renk sayisini bulmak icin bir calisma yapiniz.
#
# > Babayi ham analiz etmek cok uzun suruyorsa, pikselleri ornekleyerek analiz edebilirsiniz.

# %%
plt.imshow(baba[::5,::5,:])
plt.title("Analiz icin kabul edilebilir cozunurlukte baba");

# %% [markdown]
# # 4. Ideal renk sayisi

# %% [markdown]
# Bulmus oldugunuz ideal (oldugunu dusundugunuz) renk sayisi ile fotografi tekrar olusturunuz.

# %% [markdown]
# # 5. GMM

# %% [markdown]
# `4` numarali soruda kullanmis oldugunuz ayni renk sayisini kullanarak GMM algoritmasi ile kumeleme yapiniz.
#
# Sonuclarinizi K-Means sonuclari ile karsilastiriniz.
